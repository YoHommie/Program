# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

folder_path="C:/Users/adity/OneDrive/Desktop/Sixth Semester/CE6018 Seismic Data Analytics/Program/Week8/PBNN/EPSD plot/EPSD_Data/"
# Load the data
freqEnv_actual = pd.read_csv(folder_path+'FreqEnv/Actuals_epoch1000.csv')
freqEnv_prediction = pd.read_csv(folder_path+'FreqEnv/Predictions_epoch1000.csv')


timeEnv_actual = pd.read_csv(folder_path+'TimeEnv/Actuals_epoch1000.csv')
timeEnv_prediction = pd.read_csv(folder_path+'TimeEnv/Predictions_epoch1000.csv')
# print(freqEnv_actual.shape)
# print(freqEnv_prediction.shape)
# print(timeEnv_actual.shape)
# print(timeEnv_prediction.shape)
# Out:
# (2838, 130)
# (2838, 130)
# (2838, 228)
# (2838, 228)

# %%
row_no=1
#dorpping the the first 8 col selecting the row 



freqEnv_actual_row = freqEnv_actual.iloc[row_no][8:]
freqEnv_actual_row = freqEnv_actual_row.apply(lambda x: 10**x)
freqEnv_prediction_row = freqEnv_prediction.iloc[row_no][8:]
freqEnv_prediction_row = freqEnv_prediction_row.apply(lambda x: 10**x)

timeEnv_actual_row = timeEnv_actual.iloc[row_no][8:]
timeEnv_actual_row = timeEnv_actual_row.apply(lambda x: 10**x)

timeEnv_prediction_row = timeEnv_prediction.iloc[row_no][8:]
timeEnv_prediction_row = timeEnv_prediction_row.apply(lambda x: 10**x)

print(freqEnv_actual_row.shape, freqEnv_prediction_row.shape, timeEnv_actual_row.shape, timeEnv_prediction_row.shape)
# Out:
# (122,) (122,) (220,) (220,)

# %%
#Making a matrix of the product of the actual time and freq env
actual_matrix = np.outer(timeEnv_actual_row, freqEnv_actual_row)

#Making a matrix of the product of the predicted time and freq env
prediction_matrix = np.outer(timeEnv_prediction_row, freqEnv_prediction_row)

# print(actual_matrix.shape)
# print(prediction_matrix.shape)
# Out:
# (220, 122)
# (220, 122)

# %%
# #Plotting the actual matrix in 3d
# fig = plt.figure(figsize=(10,10))

# ax1 = fig.add_subplot(121, projection='3d')  # Changed 111,112 to 121
# x1 = np.arange(actual_matrix.shape[0])
# y1 = np.arange(actual_matrix.shape[1])
# X1, Y1 = np.meshgrid(x1, y1)
# ax1.plot_surface(X1, Y1, actual_matrix, cmap='jet')
# ax1.view_init(elev=30, azim=45)
# # Rotate the plot
# ax1.view_init(elev=60, azim=90)
# ax1.set_title('Actual Matrix')  # Changed ax1.title to ax1.set_title

# ax2 = fig.add_subplot(122, projection='3d')  # Changed 111 to 122
# x2 = np.arange(prediction_matrix.shape[0])
# y2 = np.arange(prediction_matrix.shape[1])
# X2, Y2 = np.meshgrid(x2, y2)
# ax2.plot_surface(X2, Y2, prediction_matrix, cmap='jet')
# ax2.view_init(elev=30, azim=45)
# # Rotate the plot
# ax2.view_init(elev=60, azim=90)
# ax2.set_title('Predicted Matrix')  # Changed plt.title to ax2.set_title

# plt.show()

#Plotting the actual matrix in 3d
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(121, projection='3d')
x1 = np.arange(actual_matrix.shape[0])
y1 = np.arange(actual_matrix.shape[1])
Y1, X1 = np.meshgrid(y1, x1)  # Changed the order of inputs
ax1.plot_surface(X1, Y1, actual_matrix, cmap='jet')
ax1.view_init(elev=60, azim=90)
ax1.set_title('Actual Matrix')

ax2 = fig.add_subplot(122, projection='3d')
x2 = np.arange(prediction_matrix.shape[0])
y2 = np.arange(prediction_matrix.shape[1])
Y2, X2 = np.meshgrid(y2, x2)  # Changed the order of inputs
ax2.plot_surface(X2, Y2, prediction_matrix, cmap='jet')
ax2.view_init(elev=60, azim=90)
ax2.set_title('Predicted Matrix')

plt.show()
